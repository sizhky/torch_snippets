# %% [raw]
# ---
# description: Utilities specific to jupyter
# output-file: jupyter_notebook.html
# title: Jupyter Notebooks
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(backup_folders_of_nbs)
# Out:
# ---
#
# ### backup_folders_of_nbs
#
# >      backup_folders_of_nbs (src, dest)

# %%
#| echo: false
#| output: asis
show_doc(backup_all_notebooks)
# Out:
# ---
#
# ### backup_all_notebooks
#
# >      backup_all_notebooks (folder)

# %%
#| echo: false
#| output: asis
show_doc(backup_this_notebook)
# Out:
# ---
#
# ### backup_this_notebook
#
# >      backup_this_notebook (this_file_path, save_html_to_dir=None,
# >                            override_previous_backup=False, changelog=None,
# >                            exclude_input=False, force_save_notebook=True)

# %%
#| echo: false
#| output: asis
show_doc(save_notebook)
# Out:
# ---
#
# ### save_notebook
#
# >      save_notebook (file_path)

# %%
backup_this_notebook("jupyter_notebook.ipynb")

# %%
#| echo: false
#| output: asis
show_doc(show_big_dataframe)
# Out:
# ---
#
# ### show_big_dataframe
#
# >      show_big_dataframe (df, max_rows=30)

# %%
#| echo: false
#| output: asis
show_doc(display_dfs_side_by_side)
# Out:
# ---
#
# ### display_dfs_side_by_side
#
# >      display_dfs_side_by_side (*args, titles=<itertools.cycle object at
# >                                0x137427a00>, max_rows=50)

# %%
#| echo: false
#| output: asis
show_doc(h6)
# Out:
# ---
#
# ### h6
#
# >      h6 (text)

# %%
#| echo: false
#| output: asis
show_doc(h5)
# Out:
# ---
#
# ### h5
#
# >      h5 (text)

# %%
#| echo: false
#| output: asis
show_doc(h4)
# Out:
# ---
#
# ### h4
#
# >      h4 (text)

# %%
#| echo: false
#| output: asis
show_doc(h3)
# Out:
# ---
#
# ### h3
#
# >      h3 (text)

# %%
#| echo: false
#| output: asis
show_doc(h2)
# Out:
# ---
#
# ### h2
#
# >      h2 (text)

# %%
#| echo: false
#| output: asis
show_doc(h1)
# Out:
# ---
#
# ### h1
#
# >      h1 (text)

# %%
#| echo: false
#| output: asis
show_doc(store_scrap)
# Out:
# ---
#
# ### store_scrap
#
# >      store_scrap (at)

# %%
#| echo: false
#| output: asis
show_doc(shutdown_current_notebook)
# Out:
# ---
#
# ### shutdown_current_notebook
#
# >      shutdown_current_notebook (delay:int=None)
