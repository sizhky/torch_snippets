# %% [raw]
# # Jupyter
# Check if a code is running in jupyter or not
# ---
# {}
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(is_in_notebook)
# Out:
# ---
#
# ### is_in_notebook
#
# >      is_in_notebook ()
