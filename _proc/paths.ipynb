# %% [raw]
# # Paths
# Utilities to manipulate Paths
# ---
# {}
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
print(P().ls())
print(P().resolve())
# Out:
# [» tmp.txt, » _quarto.yml, » decorators.ipynb, » markups.ipynb, » sidebar.yml, » AttrDict.ipynb, » interactive_show.ipynb, » load_defautls.ipynb, » sklegos.ipynb, » bounding_boxes.ipynb, » show.ipynb, » pdf.ipynb, » charts.ipynb, » paths.ipynb, » nbdev.yml, » tmp.csv, » jupyter_notebook.ipynb, » config.ipynb, » misc.ipynb, » registry.ipynb, » adapters.ipynb, » report.ipynb, » .ipynb_checkpoints, » capsule.ipynb, » logging.ipynb, » inspector.ipynb, » bokeh_plotting.ipynb, » index.ipynb, » imgaug_loader.ipynb]
# /Users/apple/Code/Personal/torch_snippets/nbs

# %%
# !touch tmp.txt tmp.csv

# %%
x = P()
x.tmp__csv, x.tmp__txt, x.misc
# Out:
# (» tmp.csv, » tmp.txt, » misc.ipynb)

# %%
# !rm tmp.txt tmp.misc
# Out:
# rm: tmp.misc: No such file or directory

# %%
#| echo: false
#| output: asis
show_doc(P.rm)
# Out:
# ---
#
# ### Path.rm
#
# >      Path.rm (confirm_prompt='Are you sure you want to delete `{self}`?
# >               [y/N]', silent=True, missing_ok=True, force=False,
# >               dry_run=False)

# %%
#| echo: false
#| output: asis
show_doc(remove_file)
# Out:
# ---
#
# ### remove_file
#
# >      remove_file (dry_run)

# %%
#| echo: false
#| output: asis
show_doc(P.cp)
# Out:
# ---
#
# ### Path.cp
#
# >      Path.cp (to)

# %%
#| echo: false
#| output: asis
show_doc(P.mv)
# Out:
# ---
#
# ### Path.mv
#
# >      Path.mv (to)

# %%
#| echo: false
#| output: asis
show_doc(P.sample)
# Out:
# ---
#
# ### Path.sample
#
# >      Path.sample (pattern='*')

# %%
#| echo: false
#| output: asis
show_doc(P.sz)
# Out:
# ---
#
# ### Path.sz
#
# >      Path.sz ()

# %%
#| echo: false
#| output: asis
show_doc(P.size)
# Out:
# ---
#
# ### Path.size
#
# >      Path.size ()

# %%
#| echo: false
#| output: asis
show_doc(P.rmtree)
# Out:
# ---
#
# ### Path.rmtree
#
# >      Path.rmtree (prompt='Really remove `{self}` and its contents? [y/n] ',
# >                   force=False)

# %%
p = P("test.txt")
p.touch()
logger.info(p.size())
# Out:
# [07/02/24 14:04:08] INFO     0 KB                                                                                                                   ]8;id=737086;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1417366103.py:3\1417366103.py]8;;\:]8;id=443459;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1417366103.py:3#<module>:3\<module>:3]8;;\

# %% [markdown]
# Path objects can be moved and copied

# %%
p = p.mv("test1.txt")
q = p.cp("test2.txt")

# %% [markdown]
# Path objects have a `size`, `extn` (extension) and `parent` attributes

# %%
assert isinstance(q, P)
assert q.size() == "0 KB"
assert str(p) == "test1.txt"
assert p.extn() == "txt"
assert p.parent == P()

# %% [markdown]
# They can be deleted with/without a prompt

# %%
p.rm(force=True)
q.rm(confirm_prompt=False)

# %% [markdown]
# Folders can be globbed with a default of everything

# %%
p = P("../torch_snippets")
assert P().ls() == P().Glob()
p.Glob("*.py")
# Out:
# (#30) [» ../torch_snippets/misc.py,» ../torch_snippets/load_defaults.py,» ../torch_snippets/text_utils.py,» ../torch_snippets/_nbdev.py,» ../torch_snippets/paths.py,» ../torch_snippets/charts.py,» ../torch_snippets/pdf_loader.py,» ../torch_snippets/interactive_show.py,» ../torch_snippets/registry.py,» ../torch_snippets/markup2.py,» ../torch_snippets/_modidx.py,» ../torch_snippets/inspector.py,» ../torch_snippets/__init__.py,» ../torch_snippets/tmp.py,» ../torch_snippets/torch_loader.py,» ../torch_snippets/logger.py,» ../torch_snippets/markup.py,» ../torch_snippets/fastcores.py,» ../torch_snippets/sklegos.py,» ../torch_snippets/ipython.py...]

# %% [markdown]
# You can sample a random file from the directory

# %%
q = p.sample("*.py")
Info(f"Sample file: `{q}`")
Info(f"Sample file size: `{q.size()}`")
# Out:
#                     INFO     Sample file: `../torch_snippets/load_defaults.py`                                                                      ]8;id=233689;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1725593160.py:2\1725593160.py]8;;\:]8;id=418277;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1725593160.py:2#<module>:2\<module>:2]8;;\
#                     INFO     Sample file size: `0 KB`                                                                                               ]8;id=367276;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1725593160.py:3\1725593160.py]8;;\:]8;id=268339;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1725593160.py:3#<module>:3\<module>:3]8;;\

# %%
try:
    p.size()
except Exception as e:
    logger.warning(e)
# Out:
#                     WARNING  `../torch_snippets` is a directory                                                                                     ]8;id=716931;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1980994904.py:4\1980994904.py]8;;\:]8;id=553903;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1980994904.py:4#<module>:4\<module>:4]8;;\

# %%
p = P("test.txt")
p.touch()
assert isdir(p) == False
assert fname(p) == "test.txt"
assert parent(p) == P()
assert stem(p) == "test"
assert extn(p) == "txt"

print(find("capsule", Glob("./")))

p.rm(confirm_prompt=False)
# Out:
# capsule.ipynb

# %%
#| echo: false
#| output: asis
show_doc(list_zip)
# Out:
# ---
#
# ### list_zip
#
# >      list_zip (file)

# %%
#| echo: false
#| output: asis
show_doc(unzip_file)
# Out:
# ---
#
# ### unzip_file
#
# >      unzip_file (file, dest)

# %%
#| echo: false
#| output: asis
show_doc(zip_files)
# Out:
# ---
#
# ### zip_files
#
# >      zip_files (list_of_files, dest)

# %%
# !touch test1.txt test2.txt
f = zip_files(P().Glob("*.txt"), "test.tar.gz")
unzip_file(f, "./")
[f.rm(force=True) for f in P().Glob("*.txt")]
P("test.tar.gz").rm(force=True)

# !touch test1.txt test2.txt
f = zip_files(P().Glob("*.txt"), "test.zip")
unzip_file(f, "./")
[f.rm(force=True) for f in P().Glob("*.txt")]
P("test.zip").rm(force=True)
# Out:
#                     INFO     Zipping 2 files to test.tar.gz...                                                                                     ]8;id=953020;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/3826617683.py:8\3826617683.py]8;;\:]8;id=462622;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/3826617683.py:8#zip_files:8\zip_files:8]8;;\
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 1836.39it/s]
# [07/02/24 14:04:09] INFO     Zipping 2 files to test.zip...                                                                                        ]8;id=360450;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/3826617683.py:8\3826617683.py]8;;\:]8;id=855834;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/3826617683.py:8#zip_files:8\zip_files:8]8;;\
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 851.46it/s]

# %%
#| echo: false
#| output: asis
show_doc(folder_summary)
# Out:
# ---
#
# ### folder_summary
#
# >      folder_summary (thing)

# %%
#| echo: false
#| output: asis
show_doc(common_items)
# Out:
# ---
#
# ### common_items
#
# >      common_items (*fldrs, verbose=True)

# %%
#| echo: false
#| output: asis
show_doc(remove_duplicates)
# Out:
# ---
#
# ### remove_duplicates
#
# >      remove_duplicates (files)
#
# *Check a list of files and remove duplicates based on their checksum*

# %%
#| echo: false
#| output: asis
show_doc(md5)
# Out:
# ---
#
# ### md5
#
# >      md5 (fname)

# %%
md5("paths.ipynb")
# Out:
# '02ae3f36d5fd54fe83c9349376ada016'

# %%
#| echo: false
#| output: asis
show_doc(P.write_lines)
# Out:
# ---
#
# ### Path.write_lines
#
# >      Path.write_lines (lines, mode)

# %%
#| echo: false
#| output: asis
show_doc(writelines)
# Out:
# ---
#
# ### writelines
#
# >      writelines (lines, file, mode)

# %%
#| echo: false
#| output: asis
show_doc(P.read_lines)
# Out:
# ---
#
# ### Path.read_lines
#
# >      Path.read_lines (silent=False, encoding=None)

# %%
#| echo: false
#| output: asis
show_doc(readlines)
# Out:
# ---
#
# ### readlines
#
# >      readlines (fpath, silent=False, encoding=None)

# %%
P("paths.ipynb").read_lines()[:10]
# Out:
#                     INFO     loaded 1396 lines                                                                                                    ]8;id=506043;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/276455267.py:13\276455267.py]8;;\:]8;id=409505;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/276455267.py:13#read_lines:13\read_lines:13]8;;\
# ['{',
#  '"cells": [',
#  '{',
#  '"cell_type": "raw",',
#  '"metadata": {},',
#  '"source": [',
#  '"# Paths\\n",',
#  '"Utilities to manipulate Paths\\n",',
#  '"---\\n",',
#  '"{}\\n",']

# %%
#| echo: false
#| output: asis
show_doc(tree)
# Out:
# ---
#
# ### tree
#
# >      tree (directory='./', filelimit=50, to=None)

# %%
P("../").tree
# Out:
# /Users/apple/Code/Personal/torch_snippets
#  ── LICENSE
#  ── LICENSE.txt
#  ── MANIFEST
#  ── MANIFEST.in
#  ── Makefile
#  ── README.md
#  ── Screenshot 2022-09-08 at 4.40.18 PM.png
#  ── _proc
#      ── _quarto.yml
#      ── nbdev.yml
#      ── sidebar.yml
#  ── assets
#      ── Preamble.csv
#      ── Preamble.png
#      ── avgs0.png
#      ── avgs1.png
#      ── demo.gif
#  ── backups
#      ── testing
#          ── 0000.html
#  ── build
#      ── bdist.macosx-11.1-arm64
#      ── lib
#          ── torch_snippets
#              ── __init__.py
#              ── _modidx.py
#              ── _nbdev.py
#              ── adapters.py
#              ── bb_utils.py
#              ── bokeh_loader.py
#              ── charts.py
#              ── dates.py
#              ── decorators.py
#              ── fastcores.py
#              ── icecream.py
#              ── imgaug_loader.py
#              ── inspector.py
#              ── interactive_show.py
#              ── ipython.py
#              ── load_defaults.py
#              ── loader.py
#              ── logger.py
#              ── markup.py
#              ── markup2.py
#              ── misc.py
#              ── paths.py
#              ── pdf_loader.py
#              ── registry.py
#              ── scp.py
#              ── sklegos.py
#              ── text_utils.py
#              ── thinc_parser
#                  ── __init__.py
#                  ── parser.py
#              ── torch_loader.py
#              ── trainer
#                  ── __init__.py
#                  ── capsule.py
#                  ── config.py
#                  ── hooks.py
#                  ── neural_graph.py
#              ── video.py
#  ── changelog.md
#  ── conda
#      ── torch_snippets
#          ── meta.yaml
#  ── dist
#      ── torch_snippets-0.535-py3-none-any.whl
#      ── torch_snippets-0.535.tar.gz
#  ── docker-compose.yml
#  ── docs
#      ── adapters.html
#      ── bokeh_plotting.html
#      ── bounding_boxes.html
#      ── bounding_boxes_files
#          ── figure-html
#              ── cell-6-output-1.png
#              ── cell-7-output-1.png
#              ── cell-8-output-1.png
#              ── cell-9-output-1.png
#      ── capsule.html
#      ── capsule_files
#          ── figure-html
#              ── cell-5-output-2.png
#      ── charts.html
#      ── config.html
#      ── decorators.html
#      ── imgaug_loader.html
#      ── imgaug_loader_files
#          ── figure-html
#              ── cell-3-output-1.png
#              ── cell-5-output-10.png
#              ── cell-5-output-12.png
#              ── cell-5-output-14.png
#              ── cell-5-output-16.png
#              ── cell-5-output-18.png
#              ── cell-5-output-2.png
#              ── cell-5-output-20.png
#              ── cell-5-output-22.png
#              ── cell-5-output-4.png
#              ── cell-5-output-6.png
#              ── cell-5-output-8.png
#              ── cell-6-output-1.png
#              ── cell-7-output-1.png
#              ── cell-8-output-2.png
#      ── index.html
#      ── inspector.html
#      ── interactive_show.html
#      ── jupyter_notebook.html
#      ── load_defautls.html
#      ── logging.html
#      ── markups.html
#      ── misc.html
#      ── paths.html
#      ── pdf.html
#      ── registry.html
#      ── report.html
#      ── report_files
#          ── figure-html
#              ── cell-3-output-2.png
#              ── cell-5-output-1.png
#      ── robots.txt
#      ── search.json
#      ── show.html
#      ── show_files
#          ── figure-html
#              ── cell-2-output-1.png
#              ── cell-3-output-1.png
#              ── cell-4-output-2.png
#              ── cell-4-output-4.png
#              ── cell-4-output-6.png
#              ── cell-5-output-1.png
#              ── cell-8-output-1.png
#              ── cell-9-output-1.png
#      ── site_libs
#          ── bootstrap
#              ── bootstrap-icons.css
#              ── bootstrap-icons.woff
#              ── bootstrap.min.css
#              ── bootstrap.min.js
#          ── clipboard
#              ── clipboard.min.js
#          ── quarto-html
#              ── anchor.min.js
#              ── popper.min.js
#              ── quarto-syntax-highlighting.css
#              ── quarto.js
#              ── tippy.css
#              ── tippy.umd.min.js
#          ── quarto-nav
#              ── headroom.min.js
#              ── quarto-nav.js
#          ── quarto-search
#              ── autocomplete.umd.js
#              ── fuse.min.js
#              ── quarto-search.js
#      ── sitemap.xml
#      ── sklegos.html
#  ── nbs
#      ── AttrDict.ipynb
#      ── _quarto.yml
#      ── adapters.ipynb
#      ── bokeh_plotting.ipynb
#      ── bounding_boxes.ipynb
#      ── capsule.ipynb
#      ── charts.ipynb
#      ── config.ipynb
#      ── decorators.ipynb
#      ── imgaug_loader.ipynb
#      ── index.ipynb
#      ── inspector.ipynb
#      ── interactive_show.ipynb
#      ── jupyter_notebook.ipynb
#      ── load_defautls.ipynb
#      ── logging.ipynb
#      ── markups.ipynb
#      ── misc.ipynb
#      ── nbdev.yml
#      ── paths.ipynb
#      ── pdf.ipynb
#      ── registry.ipynb
#      ── report.ipynb
#      ── show.ipynb
#      ── sidebar.yml
#      ── sklegos.ipynb
#      ── tmp.csv
#  ── quarto-macos.pkg
#  ── requirements.txt
#  ── scripts.ipynb
#  ── settings.ini
#  ── setup.cfg
#  ── setup.py
#  ── testing.ipynb
#  ── tmp.ini
#  ── torch_snippets
#      ── __init__.py
#      ── _modidx.py
#      ── _nbdev.py
#      ── adapters.py
#      ── bb_utils.py
#      ── bokeh_loader.py
#      ── charts.py
#      ── dates.py
#      ── decorators.py
#      ── fastcores.py
#      ── icecream.py
#      ── imgaug_loader.py
#      ── inspector.py
#      ── interactive_show.py
#      ── ipython.py
#      ── load_defaults.py
#      ── loader.py
#      ── logger.py
#      ── markup.py
#      ── markup2.py
#      ── misc.py
#      ── paths.py
#      ── pdf_loader.py
#      ── registry.py
#      ── scp.py
#      ── sklegos.py
#      ── text_utils.py
#      ── thinc_parser
#          ── __init__.py
#          ── parser.py
#      ── tmp.py
#      ── torch_loader.py
#      ── trainer
#          ── __init__.py
#          ── capsule.py
#          ── config.py
#          ── hooks.py
#          ── neural_graph.py
#      ── video.py
#  ── torch_snippets.egg-info
#      ── PKG-INFO
#      ── SOURCES.txt
#      ── dependency_links.txt
#      ── not-zip-safe
#      ── requires.txt
#      ── top_level.txt
#
# 36 directories, 206 files

# %%
x = P()
x.decorators.sz
# Out:
# '13 KB'

# %%
#| echo: false
#| output: asis
show_doc(folder_structure_to_json)
# Out:
# ---
#
# ### folder_structure_to_json
#
# >      folder_structure_to_json (path, output_file=None)
#
# *Creates a JSON file representing the folder structure of the given directory.*

# %%
#| echo: false
#| output: asis
show_doc(folder_structure_to_dict)
# Out:
# ---
#
# ### folder_structure_to_dict
#
# >      folder_structure_to_dict (path)
#
# *Recursively constructs a nested dictionary that represents the folder structure.*

# %%
x = P("tmp.txt")
x.touch()
x.write_lines([i for i in range(1000)], mode="w")
lines = x.read_lines()
assert lines == [f"{i}" for i in range(1000)]
logger.info(x.size())

x.rm(confirm_prompt=False)
# Out:
#                     INFO     loaded 1000 lines                                                                                                    ]8;id=709047;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/276455267.py:13\276455267.py]8;;\:]8;id=621167;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/276455267.py:13#read_lines:13\read_lines:13]8;;\
#                     INFO     3 KB                                                                                                                   ]8;id=194265;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1033976698.py:6\1033976698.py]8;;\:]8;id=238937;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/1033976698.py:6#<module>:6\<module>:6]8;;\

# %%
#| echo: false
#| output: asis
show_doc(loaddill)
# Out:
# ---
#
# ### loaddill
#
# >      loaddill (fpath)
#
# *Load a python object from a dill file*

# %%
#| echo: false
#| output: asis
show_doc(dumpdill)
# Out:
# ---
#
# ### dumpdill
#
# >      dumpdill (obj, fpath, silent=False, message='Dumped object of size
# >                ≈{fsize} @ "{fpath}" in {dumptime:.2e} seconds')
#
# *Dump a python object as a dill file (better replacement to pickle)*

# %%
p = P("test.tmp")
dumpdill([1, 2, 3], p)
y = loaddill(p)
p.rm(confirm_prompt=False)
assert y == [1, 2, 3]
# Out:
#                     INFO     Dumped object of size ≈0 KB @ "test.tmp" in 2.55e-04 seconds                                                            ]8;id=409238;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/554288780.py:2\554288780.py]8;;\:]8;id=442382;file:///var/folders/rj/v_x4x97x5mzcnq5b34yr6k900000gn/T/ipykernel_38032/554288780.py:2#<module>:2\<module>:2]8;;\
