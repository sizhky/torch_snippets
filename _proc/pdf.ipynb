# %% [raw]
# ---
# output-file: pdf.html
# title: PDF
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PDF)
# Out:
# ---
#
# ### PDF
#
# >      PDF (path, dfs=None, dpi=150)
#
# *Load a PDF file from `path` as a list of images
# Use `show` function to see the images
# **WIP***
